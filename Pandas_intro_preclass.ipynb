# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head()
#colums meanings
#sibsp = Number of Siblings/Spouses Aboard ,Gemideki Kardeş/Eş Sayısı
#patch = Number of Parents/Children Aboard
# embarked - Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.describe().T
# Out:
#           count       mean        std   min      25%      50%   75%       max
# survived  891.0   0.383838   0.486592  0.00   0.0000   0.0000   1.0    1.0000
# pclass    891.0   2.308642   0.836071  1.00   2.0000   3.0000   3.0    3.0000
# age       714.0  29.699118  14.526497  0.42  20.1250  28.0000  38.0   80.0000
# sibsp     891.0   0.523008   1.102743  0.00   0.0000   0.0000   1.0    8.0000
# parch     891.0   0.381594   0.806057  0.00   0.0000   0.0000   0.0    6.0000
# fare      891.0  32.204208  49.693429  0.00   7.9104  14.4542  31.0  512.3292

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.embark_town.value_counts()
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: embark_town, dtype: int64

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.drop(["deck", "embark_town", "who","class", "alive" ], axis=1, inplace=True)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
#      adult_male  alone
# 0          True  False
# 1         False  False
# 2         False   True
# 3         False  False
# 4          True   True
# ...

# %%
df.fare.max()
# Out:
# 512.3292

# %%
df.fare.min()
# Out:
# 0.0

# %%
df.fare.sort_values().head(20)
# Out:
# 271    0.0000
# 597    0.0000
# 302    0.0000
# 633    0.0000
# 277    0.0000
# 413    0.0000
# 674    0.0000
# 263    0.0000
# 466    0.0000
# 732    0.0000
# 179    0.0000
# 806    0.0000
# 481    0.0000
# 822    0.0000
# 815    0.0000
# 378    4.0125
# 872    5.0000
# 326    6.2375
# 843    6.4375
# 818    6.4500
# Name: fare, dtype: float64

# %%
df.fare.sort_values(ascending= False).head(20)
# Out:
# 258    512.3292
# 737    512.3292
# 679    512.3292
# 88     263.0000
# 27     263.0000
# 341    263.0000
# 438    263.0000
# 311    262.3750
# 742    262.3750
# 118    247.5208
# 299    247.5208
# 557    227.5250
# 700    227.5250
# 380    227.5250
# 716    227.5250
# 527    221.7792
# 377    211.5000
# 730    211.3375
# 779    211.3375
# 689    211.3375
# Name: fare, dtype: float64

# %%
df.fare.sort_values(ascending= False).unique()
# Out:
# array([512.3292, 263.    , 262.375 , 247.5208, 227.525 , 221.7792,
#        211.5   , 211.3375, 164.8667, 153.4625, 151.55  , 146.5208,
#        135.6333, 134.5   , 133.65  , 120.    , 113.275 , 110.8833,
#        108.9   , 106.425 ,  93.5   ,  91.0792,  90.    ,  89.1042,
#         86.5   ,  83.475 ,  83.1583,  82.1708,  81.8583,  80.    ,
#         79.65  ,  79.2   ,  78.85  ,  78.2667,  77.9583,  77.2875,
#         76.7292,  76.2917,  75.25  ,  73.5   ,  71.2833,  71.    ,
#         69.55  ,  69.3   ,  66.6   ,  65.    ,  63.3583,  61.9792,
#         61.3792,  61.175 ,  59.4   ,  57.9792,  57.    ,  56.9292,
#         56.4958,  55.9   ,  55.4417,  55.    ,  53.1   ,  52.5542,
#         52.    ,  51.8625,  51.4792,  50.4958,  50.    ,  49.5042,
#         49.5   ,  47.1   ,  46.9   ,  42.4   ,  41.5792,  40.125 ,
#         39.6875,  39.6   ,  39.4   ,  39.    ,  38.5   ,  37.0042,
#         36.75  ,  35.5   ,  35.    ,  34.6542,  34.375 ,  34.0208,
# ...

# %%
df.fare.describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: fare, dtype: float64

# %%
df.fare.plot.box(title="FARE", grid=True)
# Out:
# <AxesSubplot:title={'center':'FARE'}>

# %%
iqr=31-7.91
iqr
# Out:
# 23.09

# %%
iqr*1.5 + 31
# Out:
# 65.63499999999999

# %%
outliars = df[df.fare>65.64].fare
outliars
# Out:
# 1       71.2833
# 27     263.0000
# 31     146.5208
# 34      82.1708
# 52      76.7292
#          ...
# 846     69.5500
# 849     89.1042
# 856    164.8667
# 863     69.5500
# 879     83.1583
# Name: fare, Length: 116, dtype: float64

# %%
(df.fare > 65.63).value_counts()
# Out:
# False    775
# True     116
# Name: fare, dtype: int64

# %%
non_outliars = df[df.fare<65.63].fare
non_outliars
non_outliars.describe()
#np.median(non_outliars)
# Out:
# count    775.000000
# mean      17.822091
# std       13.578085
# min        0.000000
# 25%        7.895800
# 50%       13.000000
# 75%       26.000000
# max       65.000000
# Name: fare, dtype: float64

# %%
non_outliars2 = df[~(df.fare>65.63)].fare
non_outliars2
# Out:
# 0       7.2500
# 2       7.9250
# 3      53.1000
# 4       8.0500
# 5       8.4583
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: fare, Length: 775, dtype: float64

# %%
non_outliars.plot.box(title="FARE", grid=True);

# %%
pd.value_counts(non_outliars).plot.hist();

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#kurtulanlara bakalım
pd.value_counts(df["survived"]).plot.bar();

# %%
df.survived.mean()
# Out:
# 0.3838383838383838

# %%
df.groupby(["sex"]).mean()
# Out:
#         survived    pclass        age     sibsp     parch       fare  \
# sex
# female  0.742038  2.159236  27.915709  0.694268  0.649682  44.479818
# male    0.188908  2.389948  30.726645  0.429809  0.235702  25.523893
#
#         adult_male     alone
# sex
# female    0.000000  0.401274
# male      0.930676  0.712305

# %%
df.pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: pclass, dtype: int64

# %%
df.groupby(["sex","pclass"]).mean()
# Out:
#                survived        age     sibsp     parch        fare  \
# sex    pclass
# female 1       0.968085  34.611765  0.553191  0.457447  106.125798
#        2       0.921053  28.722973  0.486842  0.605263   21.970121
#        3       0.500000  21.750000  0.895833  0.798611   16.118810
# male   1       0.368852  41.281386  0.311475  0.278689   67.226127
#        2       0.157407  30.740707  0.342593  0.222222   19.741782
#        3       0.135447  26.507589  0.498559  0.224784   12.661633
#
#                adult_male     alone
# sex    pclass
# female 1         0.000000  0.361702
#        2         0.000000  0.421053
#        3         0.000000  0.416667
# male   1         0.975410  0.614754
#        2         0.916667  0.666667
#        3         0.919308  0.760807

# %%
df.groupby(["pclass","sex"]).mean()
# Out:
#                survived        age     sibsp     parch        fare  \
# pclass sex
# 1      female  0.968085  34.611765  0.553191  0.457447  106.125798
#        male    0.368852  41.281386  0.311475  0.278689   67.226127
# 2      female  0.921053  28.722973  0.486842  0.605263   21.970121
#        male    0.157407  30.740707  0.342593  0.222222   19.741782
# 3      female  0.500000  21.750000  0.895833  0.798611   16.118810
#        male    0.135447  26.507589  0.498559  0.224784   12.661633
#
#                adult_male     alone
# pclass sex
# 1      female    0.000000  0.361702
#        male      0.975410  0.614754
# 2      female    0.000000  0.421053
#        male      0.916667  0.666667
# 3      female    0.000000  0.416667
#        male      0.919308  0.760807

# %%
df[df["age"]<18].groupby(["sex","class"]).count()
# Out:
#                survived  pclass  age  sibsp  parch  fare  embarked  who  \
# sex    class
# female First          8       8    8      8      8     8         8    8
#        Second        12      12   12     12     12    12        12   12
#        Third         35      35   35     35     35    35        35   35
# male   First          4       4    4      4      4     4         4    4
#        Second        11      11   11     11     11    11        11   11
#        Third         43      43   43     43     43    43        43   43
#
#                adult_male  deck  embark_town  alive  alone
# sex    class
# female First            8     8            8      8      8
#        Second          12     1           12     12     12
#        Third           35     2           35     35     35
# male   First            4     4            4      4      4
#        Second          11     3           11     11     11
#        Third           43     1           43     43     43

# %%
df[df["age"]<18].groupby(["sex","class"]).mean()
# Out:
#                survived  pclass        age     sibsp     parch        fare  \
# sex    class
# female First   0.875000     1.0  14.125000  0.500000  0.875000  104.083337
#        Second  1.000000     2.0   8.333333  0.583333  1.083333   26.241667
#        Third   0.542857     3.0   8.428571  1.571429  1.057143   18.727977
# male   First   1.000000     1.0   8.230000  0.500000  2.000000  116.072900
#        Second  0.818182     2.0   4.757273  0.727273  1.000000   25.659473
#        Third   0.232558     3.0   9.963256  2.069767  1.000000   22.752523
#
#                adult_male     alone
# sex    class
# female First     0.000000  0.125000
#        Second    0.000000  0.166667
#        Third     0.000000  0.228571
# male   First     0.250000  0.000000
#        Second    0.181818  0.181818
#        Third     0.348837  0.232558

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']
